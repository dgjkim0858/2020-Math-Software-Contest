# %% [markdown]
# <a href="https://colab.research.google.com/github/dgjkim0858/2020-Math-Software-Contest/blob/main/02%EC%9E%A5_%EC%86%8C%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 코드 2-1

# %%
age = 20
print(age)

# %% [markdown]
# 코드 2-2

# %%
age = 20
print('age')

# %% [markdown]
# 코드 2-3

# %%
age = 20
print(age)
age = 21
print(age)

# %% [markdown]
# 코드 2-4

# %%
name = '홍길동'
age = 18
print(name, '나이:', age)

# %% [markdown]
# 코드 2-5

# %%
a = 100
a += 10
print(a)
a *= 2
print(a)
a //= 7
print(a)
a %= 7
print(a)

# %% [markdown]
# LAB 두 변수의 값 교환하기

# %%
a = 7
b = 11
temp = a
a = b
b = temp
print(a, b)

# %% [markdown]
# LAB 배수 구하기

# %%
a = 3
print(a)
a += 3
print(a)
a += 3
print(a)
a += 3
print(a)

# %% [markdown]
# 코드 2-9

# %%
print(type(2024))
print(type(3.14))
print(type('Python'))
print(type(True))

# %% [markdown]
# 코드 2-10

# %%
a = 20
b = 0o34
c = 0xA1
d = 0b1110
print(a, b, c, d)

# %% [markdown]
# 코드 2-11

# %%
a = 3.14
b = 1.23e5
print(a, b)

# %% [markdown]
# 코드 2-12

# %%
a = 10>20
print(a)

# %% [markdown]
# 코드 2-13

# %%
a = 'Python'
print(a)

# %% [markdown]
# 코드 2-14

# %%
print('Hi! ' + 'Python')

# %% [markdown]
# LAB 다양한 자료형

# %%
print('convergence' + 'programming')
print(23 - 25)
print(1.23 + 12.3e-1)

# %% [markdown]
# 코드 2-16

# %%
name = input('이름: ')
age = input('나이: ')
print(name, '나이:', age)

# %% [markdown]
# 코드 2-17

# %%
a = input('정수: ')
b = input('정수: ')
print(a-b)

# %% [markdown]
# 코드 2-18

# %%
a = int(input('정수: '))
b = int(input('정수: '))
print(a-b)

# %% [markdown]
# 코드 2-19

# %%
minute = float(input('분 단위 시간: '))
second = minute * 60
print(second, '초')

# %% [markdown]
# 코드 2-20

# %%
print('반갑습니다.')
score = 99
print('성적은', score, '입니다.')

# %% [markdown]
# 코드 2-21

# %%
a = 25
b = 42
print(a)
print(b)

# %% [markdown]
# 코드 2-22

# %%
a = 25
b = 42
print(a, end=' ')
print(b)

# %% [markdown]
# 코드 2-23

# %%
print('안녕!')
print()
print('파이썬')

# %% [markdown]
# 코드 2-24

# %%
name = '홍길동'
age = 20
print('이름은 ', name, '이고 나이는 ', age, '입니다.')

# %% [markdown]
# 코드 2-25

# %%
name = '홍길동'
age = 20
print(f'이름은 {name}이고 나이는 {age}입니다.')

# %% [markdown]
# LAB 원의 넓이 구하기

# %%
pi = 3.14159265
radius = int(input('원의 반지름: '))
area = pi * radius * radius
print(f'원의 넓이: {area:.3f}')

# %% [markdown]
# 코드 2-27

# %%
a = int(input('정수: '))
b = int(input('정수: '))
print(f'{a} + {b} = {a+b}')
print(f'{a} - {b} = {a-b}')
print(f'{a} * {b} = {a*b}')
print(f'{a} / {b} = {a/b}')
print(f'{a} // {b} = {a//b}')
print(f'{a} % {b} = {a%b}')
print(f'{a} ** {b} = {a**b}')

# %% [markdown]
# 코드 2-28

# %%
ave = 70 + 80 + 90 / 3
print(ave)

# %% [markdown]
# 코드 2-29

# %%
ave = (70 + 80 + 90) / 3
print(ave)

# %% [markdown]
# LAB 남녀 비율 계산하기

# %%
male_num = int(input('남성 지원자 수: '))
female_num = int(input('여성 지원자 수: '))
total = male_num + female_num
print(f'남성 비율: {male_num/total:.2f} 여성 비율: {female_num/total:.2f}')

# %% [markdown]
# LAB 성적 평균 계산하기

# %%
score1 = int(input('점수: '))
score2 = int(input('점수: '))
score3 = int(input('점수: '))
ave = (score1+score2+score3)/3
print(f'점수 평균: {ave:.2f}')

# %% [markdown]
# LAB 길이 단위 변환하기

# %%
cm = int(input('센티미터 단위 길이: '))
m = cm // 100
cm = cm % 100
print(f'{m}미터 {cm}센티미터')

# %% [markdown]
# **[플러스] 시간 단위 변환하기**

# %% [markdown]
# 분 단위 시간을 시간과 분 단위로 변환하기

# %%
min = int(input('분 단위 시간: '))
hour = min // 60
min = min % 60
print(f'{hour}시간 {min}분')

# %% [markdown]
# 초 단위 시간을 시간, 분, 초 단위로 변환하기

# %%
second = int(input('초 단위 시간: '))
hour = second // 3600
second = second % 3600
min = second // 60
second = second % 60
print(f'{hour}시간 {min}분 {second}초')

# %% [markdown]
# **[플러스] 주문 금액 계산기**

# %% [markdown]
# 주문 금액 계산기 (1)

# %%
americano = int(input('아메리카노 주문 수: '))
latte = int(input('라떼 주문 수: '))
greentea = int(input('녹차 주문 수: '))

sum = americano*2000 + latte*3000 + greentea*2500

print('주문 금액:', sum)

# %% [markdown]
# 주문 금액 계산기 (2)

# %%
americano_price = 2000
latte_price = 3000
greentea_price = 2500

sum = 0

americano_num = int(input('아메리카노 주문 수: '))
sum += americano_num * americano_price

latte_num = int(input('라떼 주문 수: '))
sum += latte_num * latte_price

greentea_num = int(input('녹차 주문 수: '))
sum += greentea_num * greentea_price

print('총 금액:', sum)

# %% [markdown]
# ---

# %% [markdown]
# **[보충] 연비 계산기**

# %% [markdown]
# 연비 계산하기

# %%
distance = int(input('주행거리(km): '))
fuel_amount = int(input('사용연료량(l): '))
fuel_efficiency = distance / fuel_amount
print(f'연비: {fuel_efficiency:.2f}km/l')

# %% [markdown]
# 주행 가능한 거리 계산하기

# %%
fuel_efficiency = float(input('연비(km/l): '))
fuel_amount = int(input('연료량(l): '))
distance = fuel_efficiency * fuel_amount
print(f'주행 가능 거리: {distance:.2f}km')
